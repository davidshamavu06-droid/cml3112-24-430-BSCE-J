# %% [markdown]
# # Week 2 proof of life

# %%
STUDENT_ID = "24/430/BSCE-J"
COHORT = "CML3112"

# %%
print("Hello from CML3112")
proof_sum = 2 + 2
print(proof_sum)
# Out:
# Hello from CML3112
# 4

# %%
readings = 12

# %%
readings = readings + 5
print(readings)
# Out:
# 17

# %% [markdown]
# My explanation: When I ran the cell for the first time, readings changed from 12 to 17 because 5 was added to it. When I ran the same cell again, the value became 22, and after the third run it became 27. This happens because the Python kernel keeps the current value of the variable between cell executions.

# %%
import csv
with open("site_inspection_log.csv", newline="") as f:
    rows = list(csv.DictReader(f))
print(len(rows))
# Out:
# 4
